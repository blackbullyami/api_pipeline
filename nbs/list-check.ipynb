# %%
import requests

# %%
path="/api/events"
base_url="http://localhost:8002"
endpoint= f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response=requests.get(endpoint)

# %%
print(response.ok)
# Out:
# True

# %%
if (response.ok):
    data =response.json()
    print(data,type(data),data.get('items'))
# Out:
# {'results': [{'id': 1, 'page': ''}, {'id': 2, 'page': ''}, {'id': 3, 'page': ''}], 'count': 3} <class 'dict'> None
