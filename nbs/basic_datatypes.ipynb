# %%
import requests

# %%
path="/api/events/12"
base_url="http://localhost:8002"
endpoint= f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events/12'

# %%
response=requests.get(endpoint)

# %%
print(response.ok)
# Out:
# True

# %%
# here in this notebook we are just checking that our endpoint is working fine or not
if (response.ok):
    data =response.json()
    print(data,type(data))
# Out:
# {'id': 12, 'page': ''} <class 'dict'>
